# %% [markdown]
# # MGCAMB v3.0 Tests
#
# In this notebook we test the new version of MGCAMB.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pylab as pil

# %%
sns.set()

# %%
def plot_test(gr,   mg,   qr, 
              gr_m, mg_m, qr_m):
    
    ax1 = plt.subplot(2,2,1)
    ax2 = plt.subplot(2,2,3)
    ax3 = plt.subplot(2,2,2)
    ax4 = plt.subplot(2,2,4)
    
    # Cls
    ax1.semilogx(gr[:,0], gr[:,1], color = 'C2')
    ax1.semilogx(mg[:,0], mg[:,1], color = 'C0')
    ax1.semilogx(qr[:,0], qr[:,1], color = 'C1')
    ax1.set_xlim(2,2500)
    ax1.set_xticklabels([])
    ax1.set_ylabel(r'$\ell(\ell + 1) C_{\ell}^{\rm TT} / 2 \pi$')
    ax1.grid(b=True, which='minor', color='white')

    
    # delta Cls
    ax3.semilogx(gr[:,0], (mg[:,1]-gr[:,1])/gr[:,1] )
    ax3.semilogx(gr[:,0], (qr[:,1]-gr[:,1])/gr[:,1] )
    ax3.set_xlim(2,2500)
    ax3.set_ylim(-0.0005,0.0005)
    ax3.set_xlabel(r'$\ell$')
    ax3.set_ylabel(r'$ \Delta C_{\ell}^{\rm TT} / C_{\ell}^{\rm TT, GR} $ ')
    ax3.grid(b=True, which='minor', color='white')
    
    # P(k)
    ax2.loglog(gr_m[:,0], gr_m[:,1], color = 'C2')
    ax2.loglog(mg_m[:,0], mg_m[:,1], color = 'C0')
    ax2.loglog(qr_m[:,0], qr_m[:,1], color = 'C1')
    ax2.set_xlim(0.0001,2)
    ax2.set_ylabel(r'$P(k)$')
    ax2.grid(b=True, which='minor', color='white')
    ax2.set_xticklabels([])
    
    #delta P(k)
    ax4.semilogx(gr_m[:,0], (mg_m[:,1]-gr_m[:,1])/gr_m[:,1], color = 'C0' )
    ax4.semilogx(gr_m[:,0], (qr_m[:,1]-gr_m[:,1])/gr_m[:,1], color = 'C1' )
    ax4.set_xlim(0.0001,2)
    ax4.set_ylim(-0.0005,0.0005)
    ax4.set_xlabel(r'$k \, [h/{\rm Mpc}]$')
    ax4.set_ylabel(r'$ \Delta P(k) / P(k)_{\rm GR} $ ')
    ax4.grid(b=True, which='minor', color='white')

    
    plt.show()

# %% [markdown]
# ## 1. Massive Neutrinos
#
# We start by checking the GR limit of the two parametrizations implemented in MGCAMB, the $\mu,\gamma$ and the $Q,R$ parametrizations.
#
# ### 1.1 $m_{\nu} = 0.060$ eV

# %%
gr = np.loadtxt('test_GR_scalCls.dat')
mg = np.loadtxt('test_GR_mugamma_scalCls.dat')
qr = np.loadtxt('test_GR_QR_scalCls.dat')

# %%
plt.semilogx(gr[:,0], gr[:,1], color = 'C2')
plt.semilogx(mg[:,0], mg[:,1], color = 'C0')
plt.semilogx(qr[:,0], qr[:,1], color = 'C1')
plt.xlim(2,2500)
plt.xlabel(r'$\ell$')
plt.ylabel(r'$\ell(\ell + 1) C_{\ell}^{\rm TT} / 2 \pi$')
plt.grid(b=True, which='minor', color='white')
plt.show()

# %%
plt.semilogx(gr[:,0], (mg[:,1]-gr[:,1])/gr[:,1] )
plt.semilogx(gr[:,0], (qr[:,1]-gr[:,1])/gr[:,1] )
#plt.plot(gr[:,0], (fr[:,1]-gr[:,1])/gr[:,1] )
plt.xlim(2,2500)
plt.ylim(-0.0005,0.0005)
plt.xlabel(r'$\ell$')
plt.ylabel(r'$ \Delta C_{\ell}^{\rm TT} / C_{\ell}^{\rm TT, GR} $ ')
plt.grid(b=True, which='minor', color='white')
pil.savefig('delta_cl_mgcamb.pdf', bbox_inches='tight')
plt.show()

# %%
gr_m = np.loadtxt('test_GR_matterpower.dat')
mg_m = np.loadtxt('test_GR_mugamma_matterpower.dat')
qr_m = np.loadtxt('test_GR_QR_matterpower.dat')

# %%
plt.loglog(gr_m[:,0], gr_m[:,1], color = 'C2')
plt.loglog(mg_m[:,0], mg_m[:,1], color = 'C0')
plt.loglog(qr_m[:,0], qr_m[:,1], color = 'C1')
plt.xlim(0.0001,1)
plt.xlabel(r'$k \, [h/{\rm Mpc}]$')
plt.ylabel(r'$P(k)$')
plt.grid(b=True, which='minor', color='white')
plt.show()

# %%
plt.semilogx(gr_m[:,0], (mg_m[:,1]-gr_m[:,1])/gr_m[:,1], color = 'C0' )
plt.semilogx(gr_m[:,0], (qr_m[:,1]-gr_m[:,1])/gr_m[:,1], color = 'C1' )
#plt.plot(gr[:,0], (fr[:,1]-gr[:,1])/gr[:,1] )
plt.xlim(0.0001,1)
plt.ylim(-0.0005,0.0005)
plt.xlabel(r'$k \, [h/{\rm Mpc}]$')
plt.ylabel(r'$ \Delta P(k) / P(k)_{\rm GR} $ ')
plt.grid(b=True, which='minor', color='white')
pil.savefig('delta_pk_mgcamb.pdf', bbox_inches='tight')
plt.show()

# %% [markdown]
# ### 1.2. $m_{\nu} = 0.120 $ eV

# %%
gr = np.loadtxt('test_GR_2_scalCls.dat')
mg = np.loadtxt('test_GR_mugamma_2_scalCls.dat')
qr = np.loadtxt('test_GR_QR_2_scalCls.dat')

# %%
plt.semilogx(gr[:,0], gr[:,1], color = 'C2')
plt.semilogx(mg[:,0], mg[:,1], color = 'C0')
plt.semilogx(qr[:,0], qr[:,1], color = 'C1')
plt.xlim(2,2500)
plt.xlabel(r'$\ell$')
plt.ylabel(r'$\ell(\ell + 1) C_{\ell}^{\rm TT} / 2 \pi$')
plt.grid(b=True, which='minor', color='white')
plt.show()

# %%
plt.semilogx(gr[:,0], (mg[:,1]-gr[:,1])/gr[:,1] )
plt.semilogx(gr[:,0], (qr[:,1]-gr[:,1])/gr[:,1] )
#plt.plot(gr[:,0], (fr[:,1]-gr[:,1])/gr[:,1] )
plt.xlim(2,2500)
plt.ylim(-0.0005,0.0005)
plt.xlabel(r'$\ell$')
plt.ylabel(r'$ \Delta C_{\ell}^{\rm TT} / C_{\ell}^{\rm TT, GR} $ ')
plt.grid(b=True, which='minor', color='white')
#pil.savefig('delta_cl_mgcamb.pdf', bbox_inches='tight')
plt.show()

# %%
gr_m = np.loadtxt('test_GR_2_matterpower.dat')
mg_m = np.loadtxt('test_GR_mugamma_2_matterpower.dat')
qr_m = np.loadtxt('test_GR_QR_2_matterpower.dat')

# %%
plt.loglog(gr_m[:,0], gr_m[:,1], color = 'C2')
plt.loglog(mg_m[:,0], mg_m[:,1], color = 'C0')
plt.loglog(qr_m[:,0], qr_m[:,1], color = 'C1')
plt.xlim(0.0001,2)
plt.xlabel(r'$k \, [h/{\rm Mpc}]$')
plt.ylabel(r'$P(k)$')
plt.grid(b=True, which='minor', color='white')
plt.show()

# %%
plt.semilogx(gr_m[:,0], (mg_m[:,1]-gr_m[:,1])/gr_m[:,1], color = 'C0' )
plt.semilogx(gr_m[:,0], (qr_m[:,1]-gr_m[:,1])/gr_m[:,1], color = 'C1' )
#plt.plot(gr[:,0], (fr[:,1]-gr[:,1])/gr[:,1] )
plt.xlim(0.0001,2)
plt.ylim(-0.0005,0.0005)
plt.xlabel(r'$k \, [h/{\rm Mpc}]$')
plt.ylabel(r'$ \Delta P(k) / P(k)_{\rm GR} $ ')
plt.grid(b=True, which='minor', color='white')
#pil.savefig('delta_pk_mgcamb.pdf', bbox_inches='tight')
plt.show()

# %% [markdown]
# ### 1.3. $m_{\nu} = 0.179$ eV

# %%
gr = np.loadtxt('test_GR_3_scalCls.dat')
mg = np.loadtxt('test_GR_mugamma_3_scalCls.dat')
qr = np.loadtxt('test_GR_QR_3_scalCls.dat')

# %%
plt.semilogx(gr[:,0], gr[:,1], color = 'C2')
plt.semilogx(mg[:,0], mg[:,1], color = 'C0')
plt.semilogx(qr[:,0], qr[:,1], color = 'C1')
plt.xlim(2,2500)
plt.xlabel(r'$\ell$')
plt.ylabel(r'$\ell(\ell + 1) C_{\ell}^{\rm TT} / 2 \pi$')
plt.grid(b=True, which='minor', color='white')
plt.show()

# %%
plt.semilogx(gr[:,0], (mg[:,1]-gr[:,1])/gr[:,1] )
plt.semilogx(gr[:,0], (qr[:,1]-gr[:,1])/gr[:,1] )
#plt.plot(gr[:,0], (fr[:,1]-gr[:,1])/gr[:,1] )
plt.xlim(2,2500)
plt.ylim(-0.0005,0.0005)
plt.xlabel(r'$\ell$')
plt.ylabel(r'$ \Delta C_{\ell}^{\rm TT} / C_{\ell}^{\rm TT, GR} $ ')
plt.grid(b=True, which='minor', color='white')
#pil.savefig('delta_cl_mgcamb.pdf', bbox_inches='tight')
plt.show()
